# %% [markdown]
# # Informe documentación
#
# - Redactar un informe que documente el proceso seguido, incluyendo explicaciones teóricas de los métodos utilizados, código, y visualizaciones.
#
# - El documento debe seguir una estructura lógica y estar diseñado para ser accesible a personas con distintos niveles de conocimiento técnico.
#
# - Incluir una sección de conclusiones donde se discutan los hallazgos más importantes y posibles aplicaciones de la investigación.
#
# - Enviar  el documento pdf al correo electrónico
